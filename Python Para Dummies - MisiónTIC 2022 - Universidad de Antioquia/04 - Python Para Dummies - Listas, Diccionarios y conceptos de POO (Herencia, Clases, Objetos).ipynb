# %%
lista = [1.75, 1.50, 1.80, 1.20, 2.3, 0.8]
print(lista)
# Out:
# [1.75, 1.5, 1.8, 1.2, 2.3, 0.8]

# %%
print(lista[2])
# Out:
# 1.8

# %%
departamentos = ["Boyaca", "Cundinamarca", "Tolima", "Santander"]
print(departamentos)
# Out:
# ['Boyaca', 'Cundinamarca', 'Tolima', 'Santander']

# %%
print(departamentos[0])
# Out:
# Boyaca

# %%
sum(lista)
# Out:
# 9.350000000000001

# %%
lista
# Out:
# [1.75, 1.5, 1.8, 1.2, 2.3, 0.8]

# %%
for numero in lista:
  print(numero)
# Out:
# 1.75
# 1.5
# 1.8
# 1.2
# 2.3
# 0.8

# %%
lista_mezcla = ["juan", 2.5, True, 3]
print(lista_mezcla)
# Out:
# ['juan', 2.5, True, 3]

# %%
departamentos = ["Boyaca", "Cundinamarca", "Tolima", "Santander"]
print(departamentos)
# Out:
# ['Boyaca', 'Cundinamarca', 'Tolima', 'Santander']

# %%
departamentos[1:3]
# Out:
# ['Cundinamarca', 'Tolima']

# %%
print(lista)
longitud = len(lista)
suma = sum(lista)
promedio = suma/longitud
print(promedio)
# Out:
# [1.75, 1.5, 1.8, 1.2, 2.3, 0.8]
# 1.5583333333333336

# %%
print(lista)
lista.insert(3, 100)
print(lista)
# Out:
# [1.75, 1.5, 1.8, 1.2, 2.3, 0.8]
# [1.75, 1.5, 1.8, 100, 1.2, 2.3, 0.8]

# %%
print(lista)
lista.append(500)
print(lista)
# Out:
# [1.75, 1.5, 1.8, 100, 1.2, 2.3, 0.8]
# [1.75, 1.5, 1.8, 100, 1.2, 2.3, 0.8, 500]

# %%
lista.remove(500)
print(lista)
# Out:
# [1.75, 1.5, 1.8, 100, 1.2, 2.3, 0.8]

# %%
lista.pop()
print(lista)
# Out:
# [1.75, 1.5, 1.8, 100, 1.2, 2.3]

# %%
suma = 0
contador = 0

for numero in lista:
  contador += 1
  if contador%2 == 0:
    suma += numero
    
numero_datos = contador
promedio = suma / numero_datos

print(promedio)
# Out:
# 17.3

# %%
len(lista)
# Out:
# 6

# %%
sum(lista)
# Out:
# 108.55

# %%
diccionario = {123: "Boyaca", 254: "Cundinamarca", 257: "Antioquia", 568:"Cauca"}
print(diccionario)
# Out:
# {123: 'Boyaca', 254: 'Cundinamarca', 257: 'Antioquia', 568: 'Cauca'}

# %%
diccionario[5] = "Santander"
print(diccionario)
# Out:
# {123: 'Boyaca', 254: 'Cundinamarca', 257: 'Antioquia', 568: 'Cauca', 5: 'Santander'}

# %%
print(diccionario[257])
# Out:
# Antioquia

# %%
len(diccionario)
# Out:
# 5

# %%
nueva_lista = list(diccionario.values())
nueva_lista
# Out:
# ['Boyaca', 'Cundinamarca', 'Antioquia', 'Cauca', 'Santander']

# %%
diccionario = {"juan": {1,75, 32, "negro", "masculino"}}
diccionario
# Out:
# {'juan': {1, 32, 75, 'masculino', 'negro'}}

# %%
nueva_lista = [1.75, 1.5, 1.8, 100, 1.2, 2.3]

# %%
for numero in nueva_lista:
  suma += numero
print(suma)
# Out:
# 320.9
